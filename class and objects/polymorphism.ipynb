# %% [markdown]
# Polymorphism
# Polymorphism provides a way to perform a single action in different forms. Polymorphism is typically achieved through method overriding and interfaces

# %%
# Method overriding

"""Child class can provide its own implementation of a method that is already defined in its parent class.
This is called method overriding. It allows the child class to modify or extend the behavior of the inherited method without changing
the parent class's code."""
# Base class
class Animal:
    def spead(self):
        return "Sound of animal"
# derived class
class Dog(Animal):
    def speak(self):
        return "Woof!!"
# derived class
class Cat(Animal):
    def speak(self):
        return "Meow!!"

# exmaple of polymorphism using method overriding
def animal_sound(animal):
    print(animal.speak())
    
    
# creating objects of derived classes
dog = Dog()
cat = Cat()
# calling the speak method of each object
print(dog.speak())  # Output: Woof!!
print(cat.speak())  # Output: Meow!!    
animal_sound(dog)  # Output: Woof!!
animal_sound(cat)  # Output: Meow!!
# Out:
# Woof!!
# Meow!!
# Woof!!
# Meow!!

# %%
# Polymorphism with functions and methods
# base class
class Shape:
    def area(self):
        return "The are a of a figure"
    
# derived cls 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
        
    def area(self):
        return self.width * self.height
    
# derived cls 2
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius ** 2
    
# fn that demonstrates polymorphism
def print_area(shape):
    print(f"The area is: {shape.area()}")   
    
# creating objects of derived classes
rect = Rectangle(4, 5)
circle = Circle(3)
# calling the print_area function with different shapes
print_area(rect)  # Output: The area is: 20
print_area(circle)  # Output: The area is: 28.26
# Out:
# The area is: 20
# The area is: 28.26

# %% [markdown]
# # Polymorphism with Abstract base classes and interfaces
# Abstract Base Classes(ABCs) are used to define common methods for a group of related objects. They can enforce that derived classes implemnet particular methods, promoting consistency across different implementations.

# %%
from abc import ABC, abstractmethod

# define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

# derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"

# derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"
    
# create objects of derived classes
car = Car()
motorcycle = Motorcycle()

# calling the start_engine method on different vehicles
print(car.start_engine())  # Output: Car engine started
print(motorcycle.start_engine())  # Output: Motorcycle engine started
# Out:
# Car engine started
# Motorcycle engine started
