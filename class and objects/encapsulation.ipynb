# %% [markdown]
# Encapsulation and Abstraction
# Encapsulation involves building data and methods that operate on the data within a single unit, while abstraction involves hiding complex implementation details ab dexposing only the necessary features.

# %% [markdown]
# Encapsulation
# Encapsulation is the concept of wrapping data(variables) and methods together as a single unit. It restricts direct accerss to soem of the object's components which is a means of preventing accidental interference and misuse of data.
